# %% [markdown]
# # <font color= 'purple'>Andrielly Pereira </font>
#
# ## <font color ='black'>Desafio FADESP Processo Seletivo</font>

# %%
# Versão linguagem Python
from platform import python_version
print('Versão de Linguagem Python Usado Neste Jupyter Notebook:', python_version())

# %% [markdown]
# ## Inicializando o Projeto

# %%
# Para atualizar um pacote, execute o comando abaixo no terminal ou prompt de comando:
# pip install -U nome_pacote

# Para instalar a versão exata de um pacote, execute o comando abaixo no terminal ou prompt de comando:
# pip install nome_pacote==versão_desejada

# Depois de instalar ou atualizar o pacote, reinicie o jupyter notebook.

# Instala o pacote watermark. 
# Esse pacote é usado para gravar as versões de outros pacotes usados neste jupyter notebook.
# !pip install -q -U watermark

# %% [markdown]
# ### Carregando os Pacotes

# %%
# manipulação e Visualização de dados
import time
import sklearn
import datetime
import numpy as np
import pandas as pd
import sqlite3
import seaborn as sns
import matplotlib as m
import matplotlib.pyplot as plt
from collections import Counter

# Machine Learning
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler

# Formatação dos Gráficos
plt.style.use('fivethirtyeight')
plt.figure(1, figsize = (15, 6))
# %matplotlib inline

# %%
# Versões dos Pacotes usados
# %reload_ext watermark
# %watermark -a "Andrielly Moraes" --iversions

# %% [markdown]
# ## Carregando os Dados

# %%
# Carregue o dataset
filename = 'https://raw.githubusercontent.com/andriellymoraespereira/desafio-fadesp-processo-seletivo/master/data/dataset_desafio_fadesp.csv'
df = pd.read_csv(filename, index_col = 0, encoding = 'latin-1')

# %% [markdown]
# Armagenando o dataset em um banco de dados chave-valor SQLite

# %%
conn = sqlite3.connect('enterprise.db')

# %%
df.to_sql(name='sales', con=conn)
# Out:
# 51290

# %%
# !sqlite3 enterprise.db ".tables"
# Out:
# sales

# %%
# salvando os dados
# !sqlite3 enterprise.db "PRAGMA table_info(sales)"
# Out:
# 0|Row ID|INTEGER|0||0
# 1|Order ID|TEXT|0||0
# 2|Order Date|TEXT|0||0
# 3|Ship Date|TEXT|0||0
# 4|Ship Mode|TEXT|0||0
# 5|Customer ID|TEXT|0||0
# 6|Customer Name|TEXT|0||0
# 7|Segment|TEXT|0||0
# 8|City|TEXT|0||0
# 9|State|TEXT|0||0
# 10|Country|TEXT|0||0
# 11|Postal Code|REAL|0||0
# 12|Market|TEXT|0||0
# 13|Region|TEXT|0||0
# 14|Product ID|TEXT|0||0
# 15|Category|TEXT|0||0
# 16|Sub-Category|TEXT|0||0
# 17|Product Name|TEXT|0||0
# 18|Sales|REAL|0||0
# 19|Quantity|INTEGER|0||0
# 20|Discount|REAL|0||0
# 21|Profit|REAL|0||0
# 22|Shipping Cost|REAL|0||0
# 23|Order Priority|TEXT|0||0

# %%
# recuperando os dados direto em um pandas dataframe
df_read = pd.read_sql('SELECT * FROM sales', con = conn)

# %%
type(df_read)
# Out:
# pandas.core.frame.DataFrame

# %%
df_read
# Out:
#        Row ID         Order ID  Order Date Ship Date       Ship Mode  \
# 0       42433     AG-2011-2040    1/1/2011  6/1/2011  Standard Class
# 1       22253    IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# 2       48883     HU-2011-1220    1/1/2011  5/1/2011    Second Class
# 3       11731  IT-2011-3647632    1/1/2011  5/1/2011    Second Class
# 4       22255    IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# ...       ...              ...         ...       ...             ...
# 51285   32593   CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286   47594     MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287    8857   MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288    6852   MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   36388   CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#       Customer ID     Customer Name      Segment         City  \
# 0        TB-11280   Toby Braunhardt     Consumer  Constantine
# 1        JH-15985       Joseph Holt     Consumer  Wagga Wagga
# 2          AT-735     Annie Thurman     Consumer     Budapest
# 3        EM-14140      Eugene Moren  Home Office    Stockholm
# 4        JH-15985       Joseph Holt     Consumer  Wagga Wagga
# ...           ...               ...          ...          ...
# 51285    EB-13975        Erica Bern    Corporate    Fairfield
# 51286     LP-7095         Liz Preis     Consumer       Agadir
# 51287    CM-12190  Charlotte Melton     Consumer      Managua
# 51288    TD-20995     Tamara Dahlen     Consumer       Juárez
# 51289    JM-15580     Jill Matthias     Consumer     Loveland
#
#                   State  ...        Product ID         Category Sub-Category  \
# 0           Constantine  ...  OFF-TEN-10000025  Office Supplies      Storage
# 1       New South Wales  ...   OFF-SU-10000618  Office Supplies     Supplies
# 2              Budapest  ...  OFF-TEN-10001585  Office Supplies      Storage
# 3             Stockholm  ...   OFF-PA-10001492  Office Supplies        Paper
# 4       New South Wales  ...   FUR-FU-10003447        Furniture  Furnishings
# ...                 ...  ...               ...              ...          ...
# 51285        California  ...   OFF-BI-10002103  Office Supplies      Binders
# 51286  Souss-Massa-Draâ  ...  OFF-WIL-10001069  Office Supplies      Binders
# 51287           Managua  ...   OFF-LA-10004182  Office Supplies       Labels
# 51288         Chihuahua  ...   OFF-LA-10000413  Office Supplies       Labels
# 51289          Colorado  ...   OFF-FA-10003472  Office Supplies    Fasteners
#
#                                           Product Name    Sales Quantity  \
# 0                                  Tenex Lockers, Blue  408.300        2
# 1                             Acme Trimmer, High Speed  120.366        3
# 2                              Tenex Box, Single Width   66.120        4
# 3                          Enermax Note Cards, Premium   44.865        3
# 4                           Eldon Light Bulb, Duo Pack  113.670        5
# ...                                                ...      ...      ...
# 51285  Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl   13.904        2
# 51286          Wilson Jones Hole Reinforcements, Clear    3.990        1
# 51287           Hon Color Coded Labels, 5000 Label Set   26.400        3
# 51288           Hon Legal Exhibit Labels, Alphabetical    7.120        1
# 51289                              Bagged Rubber Bands    3.024        3
#
#       Discount    Profit  Shipping Cost  Order Priority
# 0          0.0  106.1400          35.46          Medium
# 1          0.1   36.0360           9.72          Medium
# 2          0.0   29.6400           8.17            High
# 3          0.5  -26.0550           4.82            High
# 4          0.1   37.7700           4.70          Medium
# ...        ...       ...            ...             ...
# 51285      0.2    4.5188           0.89          Medium
# 51286      0.0    0.4200           0.49          Medium
# 51287      0.0   12.3600           0.35          Medium
# 51288      0.0    0.5600           0.20          Medium
# 51289      0.2   -0.6048           0.17          Medium
#
# [51290 rows x 24 columns]

# %%
query = """
           SELECT *
           FROM sales;
        """
df_read = pd.read_sql(query, con=conn, index_col="Row ID")
df_read
# Out:
#                Order ID  Order Date Ship Date       Ship Mode Customer ID  \
# Row ID
# 42433      AG-2011-2040    1/1/2011  6/1/2011  Standard Class    TB-11280
# 22253     IN-2011-47883    1/1/2011  8/1/2011  Standard Class    JH-15985
# 48883      HU-2011-1220    1/1/2011  5/1/2011    Second Class      AT-735
# 11731   IT-2011-3647632    1/1/2011  5/1/2011    Second Class    EM-14140
# 22255     IN-2011-47883    1/1/2011  8/1/2011  Standard Class    JH-15985
# ...                 ...         ...       ...             ...         ...
# 32593    CA-2014-115427  31-12-2014  4/1/2015  Standard Class    EB-13975
# 47594      MO-2014-2560  31-12-2014  5/1/2015  Standard Class     LP-7095
# 8857     MX-2014-110527  31-12-2014  2/1/2015    Second Class    CM-12190
# 6852     MX-2014-114783  31-12-2014  6/1/2015  Standard Class    TD-20995
# 36388    CA-2014-156720  31-12-2014  4/1/2015  Standard Class    JM-15580
#
#            Customer Name      Segment         City             State  \
# Row ID
# 42433    Toby Braunhardt     Consumer  Constantine       Constantine
# 22253        Joseph Holt     Consumer  Wagga Wagga   New South Wales
# 48883      Annie Thurman     Consumer     Budapest          Budapest
# 11731       Eugene Moren  Home Office    Stockholm         Stockholm
# 22255        Joseph Holt     Consumer  Wagga Wagga   New South Wales
# ...                  ...          ...          ...               ...
# 32593         Erica Bern    Corporate    Fairfield        California
# 47594          Liz Preis     Consumer       Agadir  Souss-Massa-Draâ
# 8857    Charlotte Melton     Consumer      Managua           Managua
# 6852       Tamara Dahlen     Consumer       Juárez         Chihuahua
# 36388      Jill Matthias     Consumer     Loveland          Colorado
#
#               Country  ...        Product ID         Category Sub-Category  \
# Row ID                 ...
# 42433         Algeria  ...  OFF-TEN-10000025  Office Supplies      Storage
# 22253       Australia  ...   OFF-SU-10000618  Office Supplies     Supplies
# 48883         Hungary  ...  OFF-TEN-10001585  Office Supplies      Storage
# 11731          Sweden  ...   OFF-PA-10001492  Office Supplies        Paper
# 22255       Australia  ...   FUR-FU-10003447        Furniture  Furnishings
# ...               ...  ...               ...              ...          ...
# 32593   United States  ...   OFF-BI-10002103  Office Supplies      Binders
# 47594         Morocco  ...  OFF-WIL-10001069  Office Supplies      Binders
# 8857        Nicaragua  ...   OFF-LA-10004182  Office Supplies       Labels
# 6852           Mexico  ...   OFF-LA-10000413  Office Supplies       Labels
# 36388   United States  ...   OFF-FA-10003472  Office Supplies    Fasteners
#
#                                            Product Name    Sales Quantity  \
# Row ID
# 42433                               Tenex Lockers, Blue  408.300        2
# 22253                          Acme Trimmer, High Speed  120.366        3
# 48883                           Tenex Box, Single Width   66.120        4
# 11731                       Enermax Note Cards, Premium   44.865        3
# 22255                        Eldon Light Bulb, Duo Pack  113.670        5
# ...                                                 ...      ...      ...
# 32593   Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl   13.904        2
# 47594           Wilson Jones Hole Reinforcements, Clear    3.990        1
# 8857             Hon Color Coded Labels, 5000 Label Set   26.400        3
# 6852             Hon Legal Exhibit Labels, Alphabetical    7.120        1
# 36388                               Bagged Rubber Bands    3.024        3
#
#        Discount    Profit  Shipping Cost  Order Priority
# Row ID
# 42433       0.0  106.1400          35.46          Medium
# 22253       0.1   36.0360           9.72          Medium
# 48883       0.0   29.6400           8.17            High
# 11731       0.5  -26.0550           4.82            High
# 22255       0.1   37.7700           4.70          Medium
# ...         ...       ...            ...             ...
# 32593       0.2    4.5188           0.89          Medium
# 47594       0.0    0.4200           0.49          Medium
# 8857        0.0   12.3600           0.35          Medium
# 6852        0.0    0.5600           0.20          Medium
# 36388       0.2   -0.6048           0.17          Medium
#
# [51290 rows x 23 columns]

# %% [markdown]
# Criando uma nova variavel para a quantidade total vendida.

# %%
query = """
           SELECT *, "Quantity" * "Sales" AS "total"
           FROM sales;
        """
df_read = pd.read_sql(query, con=conn, index_col="Row ID")
df_read
# Out:
#                Order ID  Order Date Ship Date       Ship Mode Customer ID  \
# Row ID
# 42433      AG-2011-2040    1/1/2011  6/1/2011  Standard Class    TB-11280
# 22253     IN-2011-47883    1/1/2011  8/1/2011  Standard Class    JH-15985
# 48883      HU-2011-1220    1/1/2011  5/1/2011    Second Class      AT-735
# 11731   IT-2011-3647632    1/1/2011  5/1/2011    Second Class    EM-14140
# 22255     IN-2011-47883    1/1/2011  8/1/2011  Standard Class    JH-15985
# ...                 ...         ...       ...             ...         ...
# 32593    CA-2014-115427  31-12-2014  4/1/2015  Standard Class    EB-13975
# 47594      MO-2014-2560  31-12-2014  5/1/2015  Standard Class     LP-7095
# 8857     MX-2014-110527  31-12-2014  2/1/2015    Second Class    CM-12190
# 6852     MX-2014-114783  31-12-2014  6/1/2015  Standard Class    TD-20995
# 36388    CA-2014-156720  31-12-2014  4/1/2015  Standard Class    JM-15580
#
#            Customer Name      Segment         City             State  \
# Row ID
# 42433    Toby Braunhardt     Consumer  Constantine       Constantine
# 22253        Joseph Holt     Consumer  Wagga Wagga   New South Wales
# 48883      Annie Thurman     Consumer     Budapest          Budapest
# 11731       Eugene Moren  Home Office    Stockholm         Stockholm
# 22255        Joseph Holt     Consumer  Wagga Wagga   New South Wales
# ...                  ...          ...          ...               ...
# 32593         Erica Bern    Corporate    Fairfield        California
# 47594          Liz Preis     Consumer       Agadir  Souss-Massa-Draâ
# 8857    Charlotte Melton     Consumer      Managua           Managua
# 6852       Tamara Dahlen     Consumer       Juárez         Chihuahua
# 36388      Jill Matthias     Consumer     Loveland          Colorado
#
#               Country  ...         Category Sub-Category  \
# Row ID                 ...
# 42433         Algeria  ...  Office Supplies      Storage
# 22253       Australia  ...  Office Supplies     Supplies
# 48883         Hungary  ...  Office Supplies      Storage
# 11731          Sweden  ...  Office Supplies        Paper
# 22255       Australia  ...        Furniture  Furnishings
# ...               ...  ...              ...          ...
# 32593   United States  ...  Office Supplies      Binders
# 47594         Morocco  ...  Office Supplies      Binders
# 8857        Nicaragua  ...  Office Supplies       Labels
# 6852           Mexico  ...  Office Supplies       Labels
# 36388   United States  ...  Office Supplies    Fasteners
#
#                                            Product Name    Sales Quantity  \
# Row ID
# 42433                               Tenex Lockers, Blue  408.300        2
# 22253                          Acme Trimmer, High Speed  120.366        3
# 48883                           Tenex Box, Single Width   66.120        4
# 11731                       Enermax Note Cards, Premium   44.865        3
# 22255                        Eldon Light Bulb, Duo Pack  113.670        5
# ...                                                 ...      ...      ...
# 32593   Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl   13.904        2
# 47594           Wilson Jones Hole Reinforcements, Clear    3.990        1
# 8857             Hon Color Coded Labels, 5000 Label Set   26.400        3
# 6852             Hon Legal Exhibit Labels, Alphabetical    7.120        1
# 36388                               Bagged Rubber Bands    3.024        3
#
#        Discount    Profit  Shipping Cost  Order Priority    total
# Row ID
# 42433       0.0  106.1400          35.46          Medium  816.600
# 22253       0.1   36.0360           9.72          Medium  361.098
# 48883       0.0   29.6400           8.17            High  264.480
# 11731       0.5  -26.0550           4.82            High  134.595
# 22255       0.1   37.7700           4.70          Medium  568.350
# ...         ...       ...            ...             ...      ...
# 32593       0.2    4.5188           0.89          Medium   27.808
# 47594       0.0    0.4200           0.49          Medium    3.990
# 8857        0.0   12.3600           0.35          Medium   79.200
# 6852        0.0    0.5600           0.20          Medium    7.120
# 36388       0.2   -0.6048           0.17          Medium    9.072
#
# [51290 rows x 24 columns]

# %% [markdown]
# Salvando os novos dados na tabela sales

# %%
df_read.to_sql(name='sales', con=conn, if_exists = 'replace')
# Out:
# 51290

# %%
df_read = pd.read_sql('SELECT * FROM sales', con=conn)
df_read
# Out:
#        Row ID         Order ID  Order Date Ship Date       Ship Mode  \
# 0       42433     AG-2011-2040    1/1/2011  6/1/2011  Standard Class
# 1       22253    IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# 2       48883     HU-2011-1220    1/1/2011  5/1/2011    Second Class
# 3       11731  IT-2011-3647632    1/1/2011  5/1/2011    Second Class
# 4       22255    IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# ...       ...              ...         ...       ...             ...
# 51285   32593   CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286   47594     MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287    8857   MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288    6852   MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   36388   CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#       Customer ID     Customer Name      Segment         City  \
# 0        TB-11280   Toby Braunhardt     Consumer  Constantine
# 1        JH-15985       Joseph Holt     Consumer  Wagga Wagga
# 2          AT-735     Annie Thurman     Consumer     Budapest
# 3        EM-14140      Eugene Moren  Home Office    Stockholm
# 4        JH-15985       Joseph Holt     Consumer  Wagga Wagga
# ...           ...               ...          ...          ...
# 51285    EB-13975        Erica Bern    Corporate    Fairfield
# 51286     LP-7095         Liz Preis     Consumer       Agadir
# 51287    CM-12190  Charlotte Melton     Consumer      Managua
# 51288    TD-20995     Tamara Dahlen     Consumer       Juárez
# 51289    JM-15580     Jill Matthias     Consumer     Loveland
#
#                   State  ...         Category  Sub-Category  \
# 0           Constantine  ...  Office Supplies       Storage
# 1       New South Wales  ...  Office Supplies      Supplies
# 2              Budapest  ...  Office Supplies       Storage
# 3             Stockholm  ...  Office Supplies         Paper
# 4       New South Wales  ...        Furniture   Furnishings
# ...                 ...  ...              ...           ...
# 51285        California  ...  Office Supplies       Binders
# 51286  Souss-Massa-Draâ  ...  Office Supplies       Binders
# 51287           Managua  ...  Office Supplies        Labels
# 51288         Chihuahua  ...  Office Supplies        Labels
# 51289          Colorado  ...  Office Supplies     Fasteners
#
#                                           Product Name    Sales Quantity  \
# 0                                  Tenex Lockers, Blue  408.300        2
# 1                             Acme Trimmer, High Speed  120.366        3
# 2                              Tenex Box, Single Width   66.120        4
# 3                          Enermax Note Cards, Premium   44.865        3
# 4                           Eldon Light Bulb, Duo Pack  113.670        5
# ...                                                ...      ...      ...
# 51285  Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl   13.904        2
# 51286          Wilson Jones Hole Reinforcements, Clear    3.990        1
# 51287           Hon Color Coded Labels, 5000 Label Set   26.400        3
# 51288           Hon Legal Exhibit Labels, Alphabetical    7.120        1
# 51289                              Bagged Rubber Bands    3.024        3
#
#       Discount    Profit Shipping Cost  Order Priority    total
# 0          0.0  106.1400         35.46          Medium  816.600
# 1          0.1   36.0360          9.72          Medium  361.098
# 2          0.0   29.6400          8.17            High  264.480
# 3          0.5  -26.0550          4.82            High  134.595
# 4          0.1   37.7700          4.70          Medium  568.350
# ...        ...       ...           ...             ...      ...
# 51285      0.2    4.5188          0.89          Medium   27.808
# 51286      0.0    0.4200          0.49          Medium    3.990
# 51287      0.0   12.3600          0.35          Medium   79.200
# 51288      0.0    0.5600          0.20          Medium    7.120
# 51289      0.2   -0.6048          0.17          Medium    9.072
#
# [51290 rows x 25 columns]

# %%
# fechando a conexão com o banco de dados
conn.close()

# %% [markdown]
# ### Análise Exploratória

# %% [markdown]
# Vamos explorar os dados por diferentes perspectivas e compreender um pouco mais o relacionamento entre as variáveis.

# %%
# Colunas
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'City', 'State', 'Country', 'Postal Code',
#        'Market', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
# Renomeado as colunas
df = df.rename(columns={
    "Row ID": "Row_ID",
    "Order ID": "Order_ID",
    "Order Date": "Order_Date",
    "Ship Date": "Ship_Date",
    "Ship Mode": "Ship_Mode",
    "Customer ID": "Customer_ID",
    "Customer Name": "Customer_Name",
    "Product ID": "Product_ID",
    "Sub-Category": "Sub_Category",
    "Product Name": "Product_Name",
    "Shipping Cost": "Shipping_Cost",
    "Order Priority": "Order_Priority"
})

# %%
# Verificação de total de valores únicos por coluna
df.nunique()
# Out:
# Order_ID          25035
# Order_Date         1430
# Ship_Date          1464
# Ship_Mode             4
# Customer_ID        1590
# Customer_Name       795
# Segment               3
# City               3636
# State              1094
# Country             147
# Postal Code         631
# Market                7
# Region               13
# Product_ID        10292
# Category              3
# Sub_Category         17
# Product_Name       3788
# Sales             22995
# Quantity             14
# Discount             27
# Profit            24575
# Shipping_Cost     10037
# Order_Priority        4
# dtype: int64

# %%
# Resumo das colunas numéricas
df.describe()
# Out:
#         Postal Code         Sales      Quantity      Discount        Profit  \
# count   9994.000000  51290.000000  51290.000000  51290.000000  51290.000000
# mean   55190.379428    246.490581      3.476545      0.142908     28.610982
# std    32063.693350    487.565361      2.278766      0.212280    174.340972
# min     1040.000000      0.444000      1.000000      0.000000  -6599.978000
# 25%    23223.000000     30.758625      2.000000      0.000000      0.000000
# 50%    56430.500000     85.053000      3.000000      0.000000      9.240000
# 75%    90008.000000    251.053200      5.000000      0.200000     36.810000
# max    99301.000000  22638.480000     14.000000      0.850000   8399.976000
#
#        Shipping_Cost
# count   51290.000000
# mean       26.375915
# std        57.296804
# min         0.000000
# 25%         2.610000
# 50%         7.790000
# 75%        24.450000
# max       933.570000

# %%
# Verificando dados nulos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51290 entries, 42433 to 36388
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        51290 non-null  object
#  1   Order_Date      51290 non-null  object
#  2   Ship_Date       51290 non-null  object
#  3   Ship_Mode       51290 non-null  object
#  4   Customer_ID     51290 non-null  object
#  5   Customer_Name   51290 non-null  object
#  6   Segment         51290 non-null  object
#  7   City            51290 non-null  object
#  8   State           51290 non-null  object
#  9   Country         51290 non-null  object
#  10  Postal Code     9994 non-null   float64
#  11  Market          51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Product_ID      51290 non-null  object
#  14  Category        51290 non-null  object
#  15  Sub_Category    51290 non-null  object
#  16  Product_Name    51290 non-null  object
#  17  Sales           51290 non-null  float64
#  18  Quantity        51290 non-null  int64
#  19  Discount        51290 non-null  float64
#  20  Profit          51290 non-null  float64
#  21  Shipping_Cost   51290 non-null  float64
#  22  Order_Priority  51290 non-null  object
# dtypes: float64(5), int64(1), object(17)
# memory usage: 9.4+ MB

# %% [markdown]
# Para esta análise vamos excluir a variavel Postal Code

# %%
df = df.drop(columns=['Postal Code'])

# %%
# Convertendo a coluna de data para o tipo data
df.Order_Date  = pd.to_datetime(df.Order_Date)
df.Ship_Date  = pd.to_datetime(df.Ship_Date)
# Out:
# C:\Users\Andrielly\AppData\Local\Temp\ipykernel_8176\3083514112.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.Order_Date  = pd.to_datetime(df.Order_Date)
# C:\Users\Andrielly\AppData\Local\Temp\ipykernel_8176\3083514112.py:3: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.Ship_Date  = pd.to_datetime(df.Ship_Date)

# %%
# tipos de dados
df.dtypes
# Out:
# Order_ID                  object
# Order_Date        datetime64[ns]
# Ship_Date         datetime64[ns]
# Ship_Mode                 object
# Customer_ID               object
# Customer_Name             object
# Segment                   object
# City                      object
# State                     object
# Country                   object
# Market                    object
# Region                    object
# Product_ID                object
# Category                  object
# Sub_Category              object
# Product_Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping_Cost            float64
# Order_Priority            object
# dtype: object

# %%
# Range de datas do periodo que ocorreram as vendas
print('Data Mínima:', df['Order_Date'].min())
print('Data Maxíma:', df['Order_Date'].max())
# Out:
# Data Mínima: 2011-01-01 00:00:00
# Data Maxíma: 2014-12-31 00:00:00

# %% [markdown]
# Agora vamos conhecer os valores dentro das váriaveis region, category, Ship Mode, Market

# %%
# Contagem (Region)
df['Region'].value_counts()
# Out:
# Central           11117
# South              6645
# EMEA               5029
# North              4785
# Africa             4587
# Oceania            3487
# West               3203
# Southeast Asia     3129
# East               2848
# North Asia         2338
# Central Asia       2048
# Caribbean          1690
# Canada              384
# Name: Region, dtype: int64

# %%
# Contagem (Category)
df['Category'].value_counts()
# Out:
# Office Supplies    31273
# Technology         10141
# Furniture           9876
# Name: Category, dtype: int64

# %%
# Contagem (Ship Mode)
df['Ship_Mode'].value_counts()
# Out:
# Standard Class    30775
# Second Class      10309
# First Class        7505
# Same Day           2701
# Name: Ship_Mode, dtype: int64

# %%
# Contagem (Market)
df['Market'].value_counts()
# Out:
# APAC      11002
# LATAM     10294
# EU        10000
# US         9994
# EMEA       5029
# Africa     4587
# Canada      384
# Name: Market, dtype: int64

# %% [markdown]
# Identificão dos produtos mais vendidos e analisando sua distribuição geográfica.

# %%
df.groupby(['Country','Product_Name'])['Quantity'].sum().sort_values(ascending=False).reset_index()
# Out:
#              Country                                       Product_Name  \
# 0      United States                                            Staples
# 1      United States                         KI Adjustable-Height Table
# 2      United States                            Avery Non-Stick Binders
# 3      United States                            Storex Dura Pro Binders
# 4      United States  GBC Premium Transparent Covers with Diagonal L...
# ...              ...                                                ...
# 31960    New Zealand                      Apple Headset, with Caller ID
# 31961    New Zealand                          Apple Speaker Phone, VoIP
# 31962           Togo                          Eldon Trays, Single Width
# 31963         France                           OIC Push Pins, Bulk Pack
# 31964        Morocco                         Stanley Canvas, Easy-Erase
#
#        Quantity
# 0           876
# 1            74
# 2            71
# 3            71
# 4            67
# ...         ...
# 31960         1
# 31961         1
# 31962         1
# 31963         1
# 31964         1
#
# [31965 rows x 3 columns]

# %% [markdown]
# O produto mais vendido foi Staples e, seu maior produtor é United States.

# %%
# BoxPlot do Valor da venda realizada por Modo de envio do pedido.
ax = df.plot.box(column="Sales", by="Ship_Mode", figsize=(10, 8))

# %% [markdown]
# O modo de envio classe padrão apresdentar os maiores outlirs em relação ao Valor da venda realizada.

# %%
# Correlação (tabela)
df.corr()
# Out:
# C:\Users\Andrielly\AppData\Local\Temp\ipykernel_8176\3047215162.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                   Sales  Quantity  Discount    Profit  Shipping_Cost
# Sales          1.000000  0.313577 -0.086722  0.484918       0.768073
# Quantity       0.313577  1.000000 -0.019875  0.104365       0.272649
# Discount      -0.086722 -0.019875  1.000000 -0.316490      -0.079056
# Profit         0.484918  0.104365 -0.316490  1.000000       0.354441
# Shipping_Cost  0.768073  0.272649 -0.079056  0.354441       1.000000

# %%
# Correlação (visual)
sns.pairplot(df)

# %%
# análise da relação entre Disconto(Discount) e valor da venda realisada (sales)
# Plot
plt.figure(figsize = (10, 8))
sns.set(font_scale = 1.1)
sns.jointplot(data = df, 
              x = 'Sales', 
              y = 'Discount',
              color = 'blue')

# %% [markdown]
# Observando os histogramas, podemos ver que os dados não tem distribuídos normal.
#
# Observando o gráfico de dispersão, não parece haver correlação entre as duas variáveis. Vamos confirmar calculando o coeficiente de correlação entre elas.

# %%
# Correlação
df[['Sales', 'Discount']].corr()
# Out:
#              Sales  Discount
# Sales     1.000000 -0.086722
# Discount -0.086722  1.000000

# %% [markdown]
# Há uma correlação inversa entre o Desconto realizado e  Valor da venda realizada, os descontos impulsionam as vendas.

# %%
# análise da relação entre Quantidade de produtos vendidos e o Valor do frete.
# Plot
plt.figure(figsize = (10, 8))
sns.set(font_scale = 1.1)
sns.jointplot(data = df, 
              x = 'Quantity', 
              y = 'Shipping_Cost',
              color = 'blue')

# %% [markdown]
# Observando os histogramas, podemos ver que os dados não tem distribuídos normal.
#
# Observando o gráfico de dispersão, não parece haver correlação entre as duas variáveis. Vamos confirmar calculando o coeficiente de correlação entre elas.

# %%
# Correlação
df[['Quantity', 'Shipping_Cost']].corr()
# Out:
#                Quantity  Shipping_Cost
# Quantity       1.000000       0.272649
# Shipping_Cost  0.272649       1.000000

# %% [markdown]
# Há uma baixa correlação positiva entre a Quantidade de produtos vendidose e o Valor do frete.

# %% [markdown]
# Agora vamos separamos os dados em dois conjuntos (2013 e 2014) para exibir a evolução do lucro bruto ao longo de cada ano. Plotando no mesmo gráfico podemos fazer um comparativo dos anos mês a mês.

# %%
#Selecionando apenas as vendas de 2013
df_2013 = df[df["Order_Date"].dt.year == 2013]
#Selecionando apenas as vendas de 2014
df_2014 = df[df["Order_Date"].dt.year == 2014]
# Comparativo de lucro bruto por mês
df_2013.groupby(df_2013["Order_Date"].dt.month)["Profit"].sum().plot(color='red', label='Ano 2013')
df_2014.groupby(df_2014["Order_Date"].dt.month)["Profit"].sum().plot(color='green', label='Ano 2014')
plt.title("Lucro x Mês")
plt.xlabel("Mês")
plt.ylabel("Lucro Bruto")
plt.legend()
plt.show()

# %% [markdown]
# No gráfico Lucro x Mês, verifica-se que o ano de 2014 apresentou maior lucro por mês, comparado ao ano de 2013.
